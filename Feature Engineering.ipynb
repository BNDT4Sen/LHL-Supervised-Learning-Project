# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler

diabetes_DF = pd.read_csv('cleaner_diabetes.csv')
diabetes_DF.drop('Unnamed: 0', axis = 1, inplace = True)
diabetes_DF
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72      35.000000        0  33.6
# 1              1       85             66      29.000000        0  26.6
# 2              8      183             64      20.536458        0  23.3
# 3              1       89             66      23.000000       94  28.1
# 4              0      137             40      35.000000      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 723           10      101             76      48.000000      180  32.9
# 724            2      122             70      27.000000        0  36.8
# 725            5      121             72      23.000000      112  26.2
# 726            1      126             60      20.536458        0  30.1
# 727            1       93             70      31.000000        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 723                     0.171   63        0
# 724                     0.340   27        0
# 725                     0.245   30        0
# 726                     0.349   47        1
# 727                     0.315   23        0
#
# [728 rows x 9 columns]

# %% [markdown]
# Some of what could be considered feature engineering, (i.e. handling outliers and missing values) was partially taken care of in the EDA notebook.

# %% [markdown]
# Separating the Outcome column and converting the DataFrame to an array to allow the features to be standardized.

# %%
column_list = diabetes_DF.columns
scaler = StandardScaler()

Outcome = diabetes_DF['Outcome']

Features = diabetes_DF.drop(labels = 'Outcome', axis = 1)

Features = Features.to_numpy()

# %%
Features = scaler.fit_transform(Features)

Features = pd.DataFrame(Features)

Features = pd.concat(objs = [Features, Outcome], axis = 1)

Features.columns = column_list

Features
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.635910  0.852184      -0.035402       0.877501 -0.720856  0.180300
# 1      -0.851694 -1.202736      -0.520148       0.239041 -0.720856 -0.782209
# 2       1.230951  1.993806      -0.681730      -0.661565 -0.720856 -1.235963
# 3      -0.851694 -1.072265      -0.520148      -0.399419  0.084355 -0.575957
# 4      -1.149215  0.493389      -2.620717       0.877501  0.718244  1.486563
# ..           ...       ...            ...            ...       ...       ...
# 723     1.825992 -0.680851       0.287763       2.260832  0.821036  0.084050
# 724    -0.554173  0.004122      -0.196984       0.026221 -0.720856  0.620305
# 725     0.338389 -0.028496      -0.035402      -0.399419  0.238544 -0.837209
# 726    -0.851694  0.134593      -1.004895      -0.661565 -0.720856 -0.300954
# 727    -0.851694 -0.941794      -0.196984       0.451861 -0.720856 -0.259704
#
#      DiabetesPedigreeFunction       Age  Outcome
# 0                    0.449710  1.402331        1
# 1                   -0.375105 -0.202189        0
# 2                    0.584190 -0.117741        1
# 3                   -0.924982 -1.046673        0
# 4                    5.413541 -0.033292        1
# ..                        ...       ...      ...
# 723                 -0.913028  2.500160        0
# 724                 -0.407978 -0.539983        0
# 725                 -0.691882 -0.286637        0
# 726                 -0.381082  1.148985        1
# 727                 -0.482690 -0.877776        0
#
# [728 rows x 9 columns]

# %%
Features.to_csv('model_diabetes.csv')
